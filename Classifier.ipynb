# %% [markdown]
# # Implementing a Convolutional Neural Network
# In this Jupyter Notebook we will implement a Convolutional Neural Network to classify images of cats and dogs. The purpose of this project is to later deploy the model into an Alveo U200 card using Vitis AI.

# %%
import numpy as np

# %%
import tensorflow as tf
from tensorflow import keras

# %%
# Image processing
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# We will use the RMSprop optimizer, but you can try others like SGD and Adam
#from tensorflow.keras.optimizers import SGD
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop

# Since we have two classes we will use as our loss function the Binary Cross Entropy
from tensorflow.keras.losses import BinaryCrossentropy

# %%
# We will aim for banary accuracy as evaluation metric
from tensorflow.keras.metrics import binary_accuracy

# %%
# Model Checkpoint
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Load an image from de dataset
# It is a good idea to load an image from our dataset to see how it looks.

# %%
train_path = 'dataset/train/'
file = train_path + 'dog/dog.998.jpg'

image_shape = 227

load_img(file, target_size=(image_shape,image_shape))
# Out:
# <PIL.Image.Image image mode=RGB size=227x227 at 0x7F3FBC3B4FA0>

# %% [markdown]
# ## Data preparation
# To prepare our data we use an `ImageDataGenerator` object that allow us to do image transformation on the whole dataset. We split our data into `train` and `validation`.

# %%
train_gen = ImageDataGenerator(rescale=1./255)

train_ds = train_gen.flow_from_directory(
    'dataset/train/',
    target_size=(image_shape, image_shape),
    batch_size=64,
    shuffle=True,
    class_mode='binary')


val_gen = ImageDataGenerator(rescale=1./255)

val_ds = val_gen.flow_from_directory(
    'dataset/validation/',
    target_size=(image_shape, image_shape),
    batch_size=64,
    shuffle=True,
    class_mode='binary')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %% [markdown]
# ## Checkpoint
# Checkpointing is usefull if we want to do early stoppage when our model has trained with enough accuracy. We will keep track of the `validation accuracy` of our model, and store the one with the best results.

# %%
checkpoint = ModelCheckpoint(
    'checkpoints/cat_dog_classifier{epoch:02d}_{val_binary_accuracy:.3f}.h5',
    save_best_only=True, 
    monitor='val_binary_accuracy', 
    mode='max')

# %% [markdown]
# ## Convolutional Neural Network
# We will define a CNN with the following architecture.
#
# ![CNN](images/model.png)

# %%
image_shape = 227

inputs = tf.keras.layers.Input(shape=(image_shape,image_shape,3))

conv_1 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=2, activation='relu')(inputs)
pool_1 = tf.keras.layers.MaxPool2D(pool_size=5, strides=2)(conv_1)
batch_1 = tf.keras.layers.BatchNormalization()(pool_1)

conv_2 = tf.keras.layers.Conv2D(filters=16, kernel_size=5, strides=2, activation='relu')(batch_1)
pool_2 = tf.keras.layers.MaxPool2D(pool_size=5, strides=2)(conv_2)
batch_2 = tf.keras.layers.BatchNormalization()(pool_2)

flatten_1 = tf.keras.layers.Flatten()(batch_2)

dense_1 = tf.keras.layers.Dense(500, activation='relu')(flatten_1)
drop_1 = tf.keras.layers.Dropout(0.5)(dense_1)

dense_2 = tf.keras.layers.Dense(100, activation='relu')(drop_1)
drop_2 = tf.keras.layers.Dropout(0.5)(dense_2)

dense_3 = tf.keras.layers.Dense(50, activation='relu')(drop_2)
drop_3 = tf.keras.layers.Dropout(0.5)(dense_3)

dense_4 = tf.keras.layers.Dense(5, activation='relu')(drop_3)
drop_4 = tf.keras.layers.Dropout(0.5)(dense_4)

outputs = tf.keras.layers.Dense(1, activation='sigmoid')(drop_4)

model = tf.keras.Model(inputs, outputs)
# Out:
# 2022-09-05 12:51:26.532443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:26.565247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:26.565593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:26.566938: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-05 12:51:26.567716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:26.568088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:26.568400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:27.274738: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:27.275278: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:27.275589: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 12:51:27.276092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7061 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv2d (Conv2D)             (None, 113, 113, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 55, 55, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 55, 55, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 16)        25616
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 16)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 11, 11, 16)       64
#  hNormalization)
#
#  flatten (Flatten)           (None, 1936)              0
#
#  dense (Dense)               (None, 500)               968500
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense_1 (Dense)             (None, 100)               50100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 5)                 255
#
#  dropout_3 (Dropout)         (None, 5)                 0
#
#  dense_4 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1,051,639
# Trainable params: 1,051,479
# Non-trainable params: 160
# _________________________________________________________________

# %%
# Set the optimizer
#optimizer = SGD(learning_rate=0.02, momentum=0.8)
#optimizer = Adam(learning_rate=0.01)
optimizer = RMSprop()

# Loss function cross entropy for binary data
loss = BinaryCrossentropy(from_logits=False)

# %%
# Compile the model for training
model.compile(optimizer=optimizer, loss=loss, metrics=['binary_accuracy'])

# %% [markdown]
# ## Train the model
# In this part we will train our model using the `fit` method from our `model`. We will train for `20` `epochs` with a `batchsize` of `64`.

# %%
history = model.fit(train_ds, epochs=20, validation_data=val_ds, validation_steps=50, callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 2022-09-05 12:51:29.529786: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 313/313 [==============================] - 74s 228ms/step - loss: 0.7478 - binary_accuracy: 0.5120 - val_loss: 0.6921 - val_binary_accuracy: 0.5734
# Epoch 2/20
# 313/313 [==============================] - 71s 225ms/step - loss: 0.6966 - binary_accuracy: 0.5371 - val_loss: 0.6625 - val_binary_accuracy: 0.5750
# Epoch 3/20
# 313/313 [==============================] - 69s 219ms/step - loss: 0.6581 - binary_accuracy: 0.6165 - val_loss: 0.5784 - val_binary_accuracy: 0.7234
# Epoch 4/20
# 313/313 [==============================] - 74s 235ms/step - loss: 0.5857 - binary_accuracy: 0.6849 - val_loss: 0.6734 - val_binary_accuracy: 0.6394
# Epoch 5/20
# 313/313 [==============================] - 67s 214ms/step - loss: 0.5432 - binary_accuracy: 0.7158 - val_loss: 0.5116 - val_binary_accuracy: 0.7403
# Epoch 6/20
# 313/313 [==============================] - 67s 214ms/step - loss: 0.5113 - binary_accuracy: 0.7390 - val_loss: 0.4593 - val_binary_accuracy: 0.7978
# Epoch 7/20
# 313/313 [==============================] - 65s 208ms/step - loss: 0.4735 - binary_accuracy: 0.7524 - val_loss: 0.3981 - val_binary_accuracy: 0.8250
# Epoch 8/20
# 313/313 [==============================] - 66s 210ms/step - loss: 0.4709 - binary_accuracy: 0.7626 - val_loss: 0.4016 - val_binary_accuracy: 0.8269
# Epoch 9/20
# 313/313 [==============================] - 69s 221ms/step - loss: 0.4664 - binary_accuracy: 0.7689 - val_loss: 0.3574 - val_binary_accuracy: 0.8375
# Epoch 10/20
# 313/313 [==============================] - 69s 219ms/step - loss: 0.4419 - binary_accuracy: 0.7776 - val_loss: 0.3357 - val_binary_accuracy: 0.8534
# Epoch 11/20
# 313/313 [==============================] - 67s 214ms/step - loss: 0.4289 - binary_accuracy: 0.7799 - val_loss: 0.5162 - val_binary_accuracy: 0.8203
# Epoch 12/20
# 313/313 [==============================] - 66s 209ms/step - loss: 0.4187 - binary_accuracy: 0.7817 - val_loss: 0.5944 - val_binary_accuracy: 0.7491
# Epoch 13/20
# 313/313 [==============================] - 65s 206ms/step - loss: 0.4032 - binary_accuracy: 0.7973 - val_loss: 0.2993 - val_binary_accuracy: 0.8750
# Epoch 14/20
# 313/313 [==============================] - 66s 212ms/step - loss: 0.3862 - binary_accuracy: 0.8183 - val_loss: 0.3851 - val_binary_accuracy: 0.8331
# Epoch 15/20
# 313/313 [==============================] - 66s 212ms/step - loss: 0.3631 - binary_accuracy: 0.8450 - val_loss: 0.3338 - val_binary_accuracy: 0.8750
# Epoch 16/20
# 313/313 [==============================] - 65s 209ms/step - loss: 0.3441 - binary_accuracy: 0.8551 - val_loss: 0.4107 - val_binary_accuracy: 0.8181
# Epoch 17/20
# 313/313 [==============================] - 66s 210ms/step - loss: 0.3367 - binary_accuracy: 0.8601 - val_loss: 0.9266 - val_binary_accuracy: 0.7844
# Epoch 18/20
# 313/313 [==============================] - 66s 211ms/step - loss: 0.3219 - binary_accuracy: 0.8637 - val_loss: 0.3470 - val_binary_accuracy: 0.8525
# Epoch 19/20
# 313/313 [==============================] - 69s 219ms/step - loss: 0.3067 - binary_accuracy: 0.8694 - val_loss: 0.4172 - val_binary_accuracy: 0.8634
# Epoch 20/20
# 313/313 [==============================] - 68s 218ms/step - loss: 0.3008 - binary_accuracy: 0.8709 - val_loss: 0.4045 - val_binary_accuracy: 0.8659

# %% [markdown]
# ## Evaluation:
# We can assess the performance of our model by comparing the training and validation accuracy.

# %%
import matplotlib.pyplot as plt

# %%
train_acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

# %%
plt.plot(train_acc, label='training')
plt.plot(val_acc, label='validation')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.grid('on')
plt.title('Accuracy vs. Epoch')
plt.legend()
plt.show()
